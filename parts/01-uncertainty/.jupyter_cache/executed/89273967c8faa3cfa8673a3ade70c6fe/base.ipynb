# %%
# imports
import os
import sys
import types
import json
import base64

# figure size/format
fig_width = 6.5
fig_height = 4
fig_format = 'pdf'
fig_dpi = 150
interactivity = ''
is_shiny = False
is_dashboard = False
plotly_connected = True

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = "figure"

  # IPython 7.14 deprecated set_matplotlib_formats from IPython
  try:
    from matplotlib_inline.backend_inline import set_matplotlib_formats
  except ImportError:
    # Fall back to deprecated location for older IPython versions
    from IPython.display import set_matplotlib_formats
    
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  if plotly_connected:
    pio.renderers.default = "notebook_connected"
  else:
    pio.renderers.default = "notebook"
  for template in pio.templates.keys():
    pio.templates[template].layout.margin = dict(t=30,r=0,b=0,l=0)
except Exception:
  pass

# disable itables paging for dashboards
if is_dashboard:
  try:
    from itables import options
    options.dom = 'fiBrtlp'
    options.maxBytes = 1024 * 1024
    options.language = dict(info = "Showing _TOTAL_ entries")
    options.classes = "display nowrap compact"
    options.paging = False
    options.searching = True
    options.ordering = True
    options.info = True
    options.lengthChange = False
    options.autoWidth = False
    options.responsive = True
    options.keys = True
    options.buttons = []
  except Exception:
    pass
  
  try:
    import altair as alt
    # By default, dashboards will have container sized
    # vega visualizations which allows them to flow reasonably
    theme_sentinel = '_quarto-dashboard-internal'
    def make_theme(name):
        nonTheme = alt.themes._plugins[name]    
        def patch_theme(*args, **kwargs):
            existingTheme = nonTheme()
            if 'height' not in existingTheme:
              existingTheme['height'] = 'container'
            if 'width' not in existingTheme:
              existingTheme['width'] = 'container'

            if 'config' not in existingTheme:
              existingTheme['config'] = dict()
            
            # Configure the default font sizes
            title_font_size = 15
            header_font_size = 13
            axis_font_size = 12
            legend_font_size = 12
            mark_font_size = 12
            tooltip = False

            config = existingTheme['config']

            # The Axis
            if 'axis' not in config:
              config['axis'] = dict()
            axis = config['axis']
            if 'labelFontSize' not in axis:
              axis['labelFontSize'] = axis_font_size
            if 'titleFontSize' not in axis:
              axis['titleFontSize'] = axis_font_size  

            # The legend
            if 'legend' not in config:
              config['legend'] = dict()
            legend = config['legend']
            if 'labelFontSize' not in legend:
              legend['labelFontSize'] = legend_font_size
            if 'titleFontSize' not in legend:
              legend['titleFontSize'] = legend_font_size  

            # The header
            if 'header' not in config:
              config['header'] = dict()
            header = config['header']
            if 'labelFontSize' not in header:
              header['labelFontSize'] = header_font_size
            if 'titleFontSize' not in header:
              header['titleFontSize'] = header_font_size    

            # Title
            if 'title' not in config:
              config['title'] = dict()
            title = config['title']
            if 'fontSize' not in title:
              title['fontSize'] = title_font_size

            # Marks
            if 'mark' not in config:
              config['mark'] = dict()
            mark = config['mark']
            if 'fontSize' not in mark:
              mark['fontSize'] = mark_font_size

            # Mark tooltips
            if tooltip and 'tooltip' not in mark:
              mark['tooltip'] = dict(content="encoding")

            return existingTheme
            
        return patch_theme

    # We can only do this once per session
    if theme_sentinel not in alt.themes.names():
      for name in alt.themes.names():
        alt.themes.register(name, make_theme(name))
      
      # register a sentinel theme so we only do this once
      alt.themes.register(theme_sentinel, make_theme('default'))
      alt.themes.enable('default')

  except Exception:
    pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass

# interactivity
if interactivity:
  from IPython.core.interactiveshell import InteractiveShell
  InteractiveShell.ast_node_interactivity = interactivity

# NOTE: the kernel_deps code is repeated in the cleanup.py file
# (we can't easily share this code b/c of the way it is run).
# If you edit this code also edit the same code in cleanup.py!

# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
run_path = 'L1VzZXJzL3JvYmVydHdhZGR5L05leHRjbG91ZC9yYWlkeU1jUmFpZGVyc29uL0NvZGUvRXhwZXJpbWVudGFsVGV4dFNpdGUvcGFydHMvMDEtdW5jZXJ0YWludHk='
if run_path:
  # hex-decode the path
  run_path = base64.b64decode(run_path.encode("utf-8")).decode("utf-8")
  os.chdir(run_path)

# reset state
# %reset

# shiny
# Checking for shiny by using False directly because we're after the %reset. We don't want
# to set a variable that stays in global scope.
if False:
  try:
    import htmltools as _htmltools
    import ast as _ast

    _htmltools.html_dependency_render_mode = "json"

    # This decorator will be added to all function definitions
    def _display_if_has_repr_html(x):
      try:
        # IPython 7.14 preferred import
        from IPython.display import display, HTML
      except:
        from IPython.core.display import display, HTML

      if hasattr(x, '_repr_html_'):
        display(HTML(x._repr_html_()))
      return x

    # ideally we would undo the call to ast_transformers.append
    # at the end of this block whenver an error occurs, we do 
    # this for now as it will only be a problem if the user 
    # switches from shiny to not-shiny mode (and even then likely
    # won't matter)
    import builtins
    builtins._display_if_has_repr_html = _display_if_has_repr_html

    class _FunctionDefReprHtml(_ast.NodeTransformer):
      def visit_FunctionDef(self, node):
        node.decorator_list.insert(
          0,
          _ast.Name(id="_display_if_has_repr_html", ctx=_ast.Load())
        )
        return node

      def visit_AsyncFunctionDef(self, node):
        node.decorator_list.insert(
          0,
          _ast.Name(id="_display_if_has_repr_html", ctx=_ast.Load())
        )
        return node

    ip = get_ipython()
    ip.ast_transformers.append(_FunctionDefReprHtml())

  except:
    pass

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v

  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
globals()["__spec__"] = None
# Out:
# {"/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/importlib/_bootstrap.py": 1773951449.7760878, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/importlib/_bootstrap_external.py": 1773951449.7771692, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/zipimport.py": 1773951449.3985634, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/codecs.py": 1773951449.2591426, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/encodings/aliases.py": 1773951449.5227854, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/encodings/__init__.py": 1773951449.5217168, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/encodings/utf_8.py": 1773951449.649111, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/abc.py": 1773951449.2420053, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/io.py": 1773951449.2993882, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/stat.py": 1773951449.3619676, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/_collections_abc.py": 1773951449.2270703, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/genericpath.py": 1773951449.285172, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/posixpath.py": 1773951449.3297427, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/os.py": 1773951449.318959, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/_sitebuiltins.py": 1773951449.2377546, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/encodings/utf_8_sig.py": 1773951449.650188, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/site-packages/_distutils_hack/__init__.py": 1773060413.0, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/site.py": 1773951449.352337, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/warnings.py": 1773951449.3920784, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/importlib/__init__.py": 1773951449.773917, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/importlib/machinery.py": 1773951449.7793956, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/importlib/_abc.py": 1773951449.774998, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/types.py": 1773951449.3878179, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/importlib/util.py": 1773951449.7828765, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/runpy.py": 1773951449.3436632, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/operator.py": 1773951449.3168335, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/keyword.py": 1773951449.3016565, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/reprlib.py": 1773951449.3415396, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/collections/__init__.py": 1773951449.4448385, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/functools.py": 1773951449.284101, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/enum.py": 1773951449.2774377, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/re/_constants.py": 1773951449.9399943, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/re/_parser.py": 1773951449.9410615, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/re/_casefix.py": 1773951449.9378288, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/re/_compiler.py": 1773951449.9388962, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/copyreg.py": 1773951449.2677004, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/re/__init__.py": 1773951449.9367497, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/fnmatch.py": 1773951449.2807589, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/ntpath.py": 1773951449.3125525, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/urllib/__init__.py": 1773951450.0161486, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/lib-dynload/math.cpython-312-darwin.so": 1773951466.672918, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/ipaddress.py": 1773951449.300533, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/urllib/parse.py": 1773951450.018337, "/opt/homebrew/anaconda3/envs/expphys/lib/python3.12/pathlib.py": 1773951449.3200312, "/opt/homebr ...

# %%
#| label: fig-likelihood-crb
#| fig-cap: Log-likelihood profile for the mean of $N=10$ Gaussian measurements (known $\sigma=1$). The MLE $\hat{\mu}$ is marked; the green band is the Cramér–Rao bound $\pm\sqrt{\sigma^2/N}$. The $\Delta\ln\mathcal{L} = -\tfrac{1}{2}$ line defines the 1$\sigma$ confidence interval from the likelihood.
#| echo: true

import numpy as np
import matplotlib.pyplot as plt
import pathlib

rng = np.random.default_rng(seed=42)
plt.rcParams.update({
    "font.family": "serif", "font.size": 10,
    "axes.spines.top": False, "axes.spines.right": False,
})

mu_true, sigma_known, N = 5.0, 1.0, 10
data = rng.normal(mu_true, sigma_known, N)
mu_hat = data.mean()

mu_grid = np.linspace(2.5, 7.5, 500)
log_L = np.array([-0.5 * np.sum(((data - mu) / sigma_known)**2) for mu in mu_grid])
log_L -= log_L.max()

crb_sigma = sigma_known / np.sqrt(N)

fig, ax = plt.subplots(figsize=(6.0, 3.6))
ax.plot(mu_grid, log_L, color="#1a4a7a",
        label=r"$\ln \mathcal{L}(\mu;\,\mathbf{x})$")
ax.axhline(-0.5, color="#1a4a7a", lw=0.8, ls="--", alpha=0.6)
ax.text(7.4, -0.46, r"$\Delta\ln\mathcal{L} = -1/2$",
        ha="right", fontsize=8, color="#555")
ax.axvline(mu_hat, color="#c75000", lw=1.2, ls=":",
           label=fr"MLE $\hat{{\mu}}={mu_hat:.2f}$")
ax.axvspan(mu_hat - crb_sigma, mu_hat + crb_sigma, color="#2e7d32",
           alpha=0.12,
           label=fr"CRB: $\sigma_\mathrm{{CRB}}={crb_sigma:.3f}$")
ax.axvline(mu_true, color="#888", lw=0.9, ls="-.",
           label=fr"True $\mu_0={mu_true}$")
ax.set_xlabel(r"$\mu$")
ax.set_ylabel(r"Normalised $\ln\mathcal{L}$")
ax.set_ylim(-3.5, 0.3)
ax.legend(frameon=False, fontsize=8)
plt.tight_layout()
plt.show()
